# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing

#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    # resize and normalize the images
    transform = transforms.Compose([transforms.Resize(image_size), # resize to 128x128
                                    transforms.ToTensor()])
    train_dataset = datasets.ImageFolder(data_dir, transform)
    batch_size = 128
    num_workers= 0
    # TODO: Implement function and return a dataloader
    # build DataLoaders for SVHN dataset
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                               batch_size=batch_size,
                                               shuffle=True,
                                               num_workers=num_workers)
    return train_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128 
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min1,max1  =feature_range
    x =(max1-min1)*x +min1
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9529)
# Max:  tensor(0.8667)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv_layer(in_channels,out_channels,kernel_size=4,stride=2,padding=1,batch_norm=True):
        layer =[]
        conv  =nn.Conv2d(in_channels,out_channels,kernel_size,stride,padding)
        layer.append(conv)
        if(batch_norm==True):
            layer.append(nn.BatchNorm2d(out_channels))
        return nn.Sequential(*layer)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv1  = conv_layer(3,conv_dim,kernel_size=4,stride=2,padding=1,batch_norm=False)
        self.conv2  = conv_layer(conv_dim,conv_dim*2,kernel_size=4,stride=2,padding=1,batch_norm=True)
        self.conv3  = conv_layer(conv_dim*2,conv_dim*4,kernel_size=4,stride=2,padding=1,batch_norm=True)
        self.conv4  = conv_layer(conv_dim*4,conv_dim*8,kernel_size=4,stride=2,padding=1,batch_norm=True)
        self.fc     = nn.Linear(2*2*conv_dim*8,1)
        self.conv_dim = conv_dim

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        #print(x.shape)
        x = F.leaky_relu(self.conv1(x),0.2)
        x = F.leaky_relu(self.conv2(x),0.2)
        x = F.leaky_relu(self.conv3(x),0.2)
        x = F.leaky_relu(self.conv4(x),0.2)
        x = x.view(-1,self.conv_dim*8*2*2)
        x = self.fc(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv_layer(in_channels,out_channels,kernel_size,stride,padding,batch_norm=True):
    layer =[]
    deconv = nn.ConvTranspose2d(in_channels,out_channels,kernel_size,stride,padding)
    layer.append(deconv)
    if(batch_norm==True):
        layer.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layer)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        self.fc   = nn.Linear(z_size,1*1*16*conv_dim)
        self.dec1 = deconv_layer(16*conv_dim,8*conv_dim,kernel_size=4,stride=2,padding=1,batch_norm=True)
        self.dec2 = deconv_layer(8*conv_dim,4*conv_dim,kernel_size=4,stride=2,padding=1,batch_norm=True)
        self.dec3 = deconv_layer(4*conv_dim,2*conv_dim,kernel_size=4,stride=2,padding=1,batch_norm=True)
        self.dec4 = deconv_layer(2*conv_dim,conv_dim,kernel_size=4,stride=2,padding=1,batch_norm=True)
        self.dec5 = deconv_layer(conv_dim,3,kernel_size=4,stride=2,padding=1,batch_norm=False)
        # complete init function
        self.z_size   = z_size
        self.conv_dim = conv_dim
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x =x.view(-1,self.z_size)
        x = F.relu(self.fc(x))
        #print(x.shape)
        x =x.view(-1,16*self.conv_dim,1,1)
        #print(x.shape)
        x = F.relu( self.dec1(x))
        #print(x.shape)
        x = F.relu( self.dec2(x)) 
        x = F.relu( self.dec3(x))
        x = F.relu( self.dec4(x))
        #print(x.shape)
        x = F.tanh( self.dec5(x))
        #print(x.shape)
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    #print(type(classname))
    
    if((isinstance(m,nn.Linear)) or (isinstance(m,nn.Conv2d))):
        m.weight.data.normal_(0,0.02)
        m.bias.data.fill_(0)
        
    # TODO: Apply initial weights to convolutional and linear layers

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 256
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=4096, bias=True)
#   (dec1): Sequential(
#     (0): ConvTranspose2d(4096, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec2): Sequential(
#     (0): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec3): Sequential(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec4): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec5): Sequential(
#     (0): ConvTranspose2d(256, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch
from torch.optim import lr_scheduler
# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    criterion = nn.BCEWithLogitsLoss()
    #print(D_out.shape)
    
    labels    = torch.ones(D_out.shape[0])
    #labels    = labels.type(torch.LongTensor)
    #print(labels.type())
    if train_on_gpu:
        labels = labels.cuda()
    loss = criterion(D_out.squeeze(),labels)
    #print(D_out)
    #loss = torch.mean((D_out-1)**2)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    criterion = nn.BCEWithLogitsLoss()
    labels    = torch.zeros(D_out.shape[0])
    if train_on_gpu:
        labels = labels.cuda()
    loss = criterion(D_out.squeeze(),labels)
    #loss = torch.mean((D_out-0)**2)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim
lr      = .0002
beta1   = 0.5
beta2   = 0.999
# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(),lr,[beta1, beta2])
g_optimizer = optim.Adam(G.parameters(),lr,[beta1, beta2])
d_scheduler = lr_scheduler.StepLR(d_optimizer, step_size=2, gamma=0.5)
g_scheduler = lr_scheduler.StepLR(g_optimizer, step_size=2, gamma=0.5)

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs,d_scheduler,g_scheduler, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):
        d_scheduler.step()
        g_scheduler.step()
        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            if train_on_gpu:
                real_images = real_images.cuda()
        

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            d_out_real =D(real_images)
            d_loss_real = real_loss(d_out_real)
            
            z = np.random.uniform(-1, 1, size=(sample_size, z_size))
            z = torch.from_numpy(z).float()
            # move z to GPU if available
            if train_on_gpu:
                z = z.cuda()
            d_out_fake = D(G(z))
            d_loss_fake = fake_loss(d_out_fake)
            
            d_loss = d_loss_real+ d_loss_fake
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            z = np.random.uniform(-1, 1, size=(sample_size, z_size))
            z = torch.from_numpy(z).float()
            # move z to GPU if available
            if train_on_gpu:
                z = z.cuda()
            g_optimizer.zero_grad()
            g_out_fake = D(G(z))
            g_loss = real_loss(g_out_fake)
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples4.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return loss
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
from workspace_utils import active_session
 
with active_session():
   # set number of epochs 
    n_epochs = 18
    losses = train(D, G, n_epochs,d_scheduler,g_scheduler)
# Out:
# Epoch [    1/   18] | d_loss: 1.5349 | g_loss: 1.6292
# Epoch [    1/   18] | d_loss: 1.2318 | g_loss: 2.2748
# Epoch [    1/   18] | d_loss: 1.2806 | g_loss: 1.1636
# Epoch [    1/   18] | d_loss: 1.5814 | g_loss: 1.1481
# Epoch [    1/   18] | d_loss: 1.2820 | g_loss: 1.1228
# Epoch [    1/   18] | d_loss: 1.5037 | g_loss: 1.2382
# Epoch [    1/   18] | d_loss: 1.3891 | g_loss: 1.1377
# Epoch [    1/   18] | d_loss: 1.1882 | g_loss: 1.1977
# Epoch [    1/   18] | d_loss: 1.5672 | g_loss: 1.5626
# Epoch [    1/   18] | d_loss: 1.1744 | g_loss: 1.4349
# Epoch [    1/   18] | d_loss: 1.0380 | g_loss: 1.8364
# Epoch [    1/   18] | d_loss: 1.0188 | g_loss: 1.9858
# Epoch [    1/   18] | d_loss: 0.9545 | g_loss: 1.7271
# Epoch [    1/   18] | d_loss: 1.4067 | g_loss: 1.2970
# Epoch [    1/   18] | d_loss: 1.3616 | g_loss: 1.3082
# Epoch [    2/   18] | d_loss: 1.2902 | g_loss: 1.5580
# Epoch [    2/   18] | d_loss: 1.0423 | g_loss: 1.4729
# Epoch [    2/   18] | d_loss: 1.1258 | g_loss: 1.7452
# Epoch [    2/   18] | d_loss: 1.0830 | g_loss: 1.4976
# Epoch [    2/   18] | d_loss: 0.8191 | g_loss: 2.0452
# Epoch [    2/   18] | d_loss: 1.0861 | g_loss: 1.5259
# Epoch [    2/   18] | d_loss: 1.1278 | g_loss: 1.4466
# Epoch [    2/   18] | d_loss: 1.1649 | g_loss: 1.5639
# Epoch [    2/   18] | d_loss: 0.8913 | g_loss: 1.8372
# Epoch [    2/   18] | d_loss: 1.1198 | g_loss: 1.9152
# Epoch [    2/   18] | d_loss: 0.9180 | g_loss: 1.7567
# Epoch [    2/   18] | d_loss: 1.2585 | g_loss: 2.1501
# Epoch [    2/   18] | d_loss: 1.1085 | g_loss: 2.0058
# Epoch [    2/   18] | d_loss: 0.8889 | g_loss: 1.7587
# Epoch [    2/   18] | d_loss: 1.1051 | g_loss: 1.6047
# Epoch [    3/   18] | d_loss: 1.0093 | g_loss: 1.3916
# Epoch [    3/   18] | d_loss: 0.7580 | g_loss: 1.5257
# Epoch [    3/   18] | d_loss: 1.1252 | g_loss: 1.5786
# Epoch [    3/   18] | d_loss: 1.2416 | g_loss: 1.5239
# Epoch [    3/   18] | d_loss: 0.8264 | g_loss: 1.5343
# Epoch [    3/   18] | d_loss: 0.8965 | g_loss: 1.4516
# Epoch [    3/   18] | d_loss: 0.7786 | g_loss: 1.2289
# Epoch [    3/   18] | d_loss: 0.8482 | g_loss: 0.8733
# Epoch [    3/   18] | d_loss: 0.9158 | g_loss: 1.4078
# Epoch [    3/   18] | d_loss: 1.2062 | g_loss: 1.8921
# Epoch [    3/   18] | d_loss: 1.3488 | g_loss: 1.3491
# Epoch [    3/   18] | d_loss: 0.9577 | g_loss: 1.5103
# Epoch [    3/   18] | d_loss: 1.3306 | g_loss: 1.3153
# Epoch [    3/   18] | d_loss: 0.9616 | g_loss: 1.5689
# Epoch [    3/   18] | d_loss: 1.0422 | g_loss: 1.3323
# Epoch [    4/   18] | d_loss: 1.0733 | g_loss: 1.2863
# Epoch [    4/   18] | d_loss: 1.1125 | g_loss: 1.1171
# Epoch [    4/   18] | d_loss: 1.1418 | g_loss: 1.5777
# Epoch [    4/   18] | d_loss: 1.2899 | g_loss: 1.2030
# Epoch [    4/   18] | d_loss: 1.0048 | g_loss: 1.7456
# Epoch [    4/   18] | d_loss: 1.0395 | g_loss: 0.8223
# Epoch [    4/   18] | d_loss: 0.8229 | g_loss: 1.2814
# Epoch [    4/   18] | d_loss: 1.1763 | g_loss: 2.2404
# Epoch [    4/   18] | d_loss: 1.1215 | g_loss: 1.4487
# Epoch [    4/   18] | d_loss: 1.0469 | g_loss: 1.6838
# Epoch [    4/   18] | d_loss: 0.9455 | g_loss: 2.6660
# Epoch [    4/   18] | d_loss: 1.0426 | g_loss: 1.0182
# Epoch [    4/   18] | d_loss: 0.5867 | g_loss: 1.9909
# Epoch [    4/   18] | d_loss: 0.8054 | g_loss: 2.2166
# Epoch [    4/   18] | d_loss: 1.1424 | g_loss: 2.2433
# Epoch [    5/   18] | d_loss: 0.8708 | g_loss: 1.5150
# Epoch [    5/   18] | d_loss: 0.7220 | g_loss: 1.9152
# Epoch [    5/   18] | d_loss: 0.6985 | g_loss: 0.9144
# Epoch [    5/   18] | d_loss: 0.8695 | g_loss: 1.1490
# Epoch [    5/   18] | d_loss: 0.7358 | g_loss: 1.1678
# Epoch [    5/   18] | d_loss: 0.7140 | g_loss: 1.8270
# Epoch [    5/   18] | d_loss: 0.4650 | g_loss: 1.9504
# Epoch [    5/   18] | d_loss: 0.3246 | g_loss: 2.7579
# Epoch [    5/   18] | d_loss: 0.3465 | g_loss: 2.3281
# Epoch [    5/   18] | d_loss: 0.8481 | g_loss: 1.9951
# Epoch [    5/   18] | d_loss: 0.4879 | g_loss: 2.1921
# Epoch [    5/   18] | d_loss: 0.5420 | g_loss: 2.3731
# Epoch [    5/   18] | d_loss: 0.6806 | g_loss: 1.0040
# Epoch [    5/   18] | d_loss: 0.4509 | g_loss: 1.1797
# Epoch [    5/   18] | d_loss: 0.6166 | g_loss: 1.7461
# Epoch [    6/   18] | d_loss: 1.4502 | g_loss: 1.4889
# Epoch [    6/   18] | d_loss: 0.2550 | g_loss: 1.8823
# Epoch [    6/   18] | d_loss: 0.4447 | g_loss: 1.4075
# Epoch [    6/   18] | d_loss: 0.4949 | g_loss: 1.3395
# Epoch [    6/   18] | d_loss: 0.4123 | g_loss: 2.4560
# Epoch [    6/   18] | d_loss: 0.4872 | g_loss: 1.9622
# Epoch [    6/   18] | d_loss: 0.5322 | g_loss: 2.9371
# Epoch [    6/   18] | d_loss: 0.7156 | g_loss: 2.8587
# Epoch [    6/   18] | d_loss: 0.4289 | g_loss: 2.2953
# Epoch [    6/   18] | d_loss: 0.5137 | g_loss: 2.6664
# Epoch [    6/   18] | d_loss: 0.7932 | g_loss: 1.8913
# Epoch [    6/   18] | d_loss: 0.5738 | g_loss: 2.9918
# Epoch [    6/   18] | d_loss: 0.3405 | g_loss: 3.0479
# Epoch [    6/   18] | d_loss: 0.2855 | g_loss: 2.7745
# Epoch [    6/   18] | d_loss: 0.2502 | g_loss: 2.6045
# Epoch [    7/   18] | d_loss: 0.4494 | g_loss: 2.4987
# Epoch [    7/   18] | d_loss: 0.2871 | g_loss: 2.8343
# Epoch [    7/   18] | d_loss: 0.2522 | g_loss: 2.1221
# Epoch [    7/   18] | d_loss: 0.2143 | g_loss: 2.3072
# Epoch [    7/   18] | d_loss: 0.8539 | g_loss: 1.4377
# Epoch [    7/   18] | d_loss: 0.2053 | g_loss: 2.3934
# Epoch [    7/   18] | d_loss: 0.3947 | g_loss: 2.2054
# Epoch [    7/   18] | d_loss: 0.1973 | g_loss: 2.1757
# Epoch [    7/   18] | d_loss: 0.3281 | g_loss: 3.6533
# Epoch [    7/   18] | d_loss: 0.2939 | g_loss: 2.7023
# Epoch [    7/   18] | d_loss: 0.3037 | g_loss: 1.4296
# Epoch [    7/   18] | d_loss: 0.5749 | g_loss: 2.6482
# Epoch [    7/   18] | d_loss: 0.0595 | g_loss: 2.9967
# Epoch [    7/   18] | d_loss: 0.1745 | g_loss: 2.6039
# Epoch [    7/   18] | d_loss: 0.1016 | g_loss: 2.2470
# Epoch [    8/   18] | d_loss: 0.1284 | g_loss: 2.1961
# Epoch [    8/   18] | d_loss: 0.2380 | g_loss: 2.2535
# Epoch [    8/   18] | d_loss: 0.8320 | g_loss: 2.7274
# Epoch [    8/   18] | d_loss: 0.1399 | g_loss: 3.9444
# Epoch [    8/   18] | d_loss: 0.0984 | g_loss: 2.0203
# Epoch [    8/   18] | d_loss: 0.3233 | g_loss: 2.2750
# Epoch [    8/   18] | d_loss: 0.3133 | g_loss: 3.2102
# Epoch [    8/   18] | d_loss: 0.3096 | g_loss: 5.1284
# Epoch [    8/   18] | d_loss: 0.2712 | g_loss: 2.5443
# Epoch [    8/   18] | d_loss: 0.8749 | g_loss: 1.8985
# Epoch [    8/   18] | d_loss: 0.1372 | g_loss: 2.6290
# Epoch [    8/   18] | d_loss: 0.1251 | g_loss: 3.6727
# Epoch [    8/   18] | d_loss: 1.1317 | g_loss: 5.2115
# Epoch [    8/   18] | d_loss: 0.2828 | g_loss: 2.5165
# Epoch [    8/   18] | d_loss: 0.0819 | g_loss: 3.7207
# Epoch [    9/   18] | d_loss: 0.0853 | g_loss: 2.3979
# Epoch [    9/   18] | d_loss: 0.3582 | g_loss: 2.8936
# Epoch [    9/   18] | d_loss: 0.7348 | g_loss: 2.3137
# Epoch [    9/   18] | d_loss: 0.1141 | g_loss: 3.6925
# Epoch [    9/   18] | d_loss: 0.0665 | g_loss: 2.9027
# Epoch [    9/   18] | d_loss: 0.0618 | g_loss: 2.8222
# Epoch [    9/   18] | d_loss: 0.2619 | g_loss: 3.1670
# Epoch [    9/   18] | d_loss: 0.2850 | g_loss: 2.1647
# Epoch [    9/   18] | d_loss: 0.2244 | g_loss: 2.2853
# Epoch [    9/   18] | d_loss: 0.0739 | g_loss: 3.3476
# Epoch [    9/   18] | d_loss: 0.1550 | g_loss: 2.6700
# Epoch [    9/   18] | d_loss: 1.0882 | g_loss: 2.5147
# Epoch [    9/   18] | d_loss: 0.0453 | g_loss: 1.7284
# Epoch [    9/   18] | d_loss: 0.1416 | g_loss: 1.9269
# Epoch [    9/   18] | d_loss: 0.0252 | g_loss: 2.8183
# Epoch [   10/   18] | d_loss: 0.5843 | g_loss: 3.5819
# Epoch [   10/   18] | d_loss: 0.1926 | g_loss: 4.5819
# Epoch [   10/   18] | d_loss: 0.1450 | g_loss: 2.1282
# Epoch [   10/   18] | d_loss: 0.0894 | g_loss: 4.2047
# Epoch [   10/   18] | d_loss: 0.0465 | g_loss: 2.5485
# Epoch [   10/   18] | d_loss: 0.2934 | g_loss: 3.8410
# Epoch [   10/   18] | d_loss: 0.0229 | g_loss: 3.3265
# Epoch [   10/   18] | d_loss: 0.2555 | g_loss: 3.6793
# Epoch [   10/   18] | d_loss: 0.0380 | g_loss: 4.2654
# Epoch [   10/   18] | d_loss: 0.0411 | g_loss: 4.3881
# Epoch [   10/   18] | d_loss: 0.1802 | g_loss: 4.6350
# Epoch [   10/   18] | d_loss: 0.4499 | g_loss: 1.4406
# Epoch [   10/   18] | d_loss: 0.0968 | g_loss: 3.6820
# Epoch [   10/   18] | d_loss: 0.1518 | g_loss: 6.0029
# Epoch [   10/   18] | d_loss: 0.1928 | g_loss: 2.0365
# Epoch [   11/   18] | d_loss: 0.1974 | g_loss: 5.0152
# Epoch [   11/   18] | d_loss: 0.0753 | g_loss: 2.4476
# Epoch [   11/   18] | d_loss: 0.2700 | g_loss: 3.0529
# Epoch [   11/   18] | d_loss: 0.0232 | g_loss: 4.5326
# Epoch [   11/   18] | d_loss: 0.5421 | g_loss: 2.8275
# Epoch [   11/   18] | d_loss: 0.1933 | g_loss: 2.2228
# Epoch [   11/   18] | d_loss: 0.1184 | g_loss: 2.8361
# Epoch [   11/   18] | d_loss: 0.1549 | g_loss: 3.0931
# Epoch [   11/   18] | d_loss: 0.2522 | g_loss: 3.1119
# Epoch [   11/   18] | d_loss: 0.0527 | g_loss: 3.7403
# Epoch [   11/   18] | d_loss: 0.0397 | g_loss: 4.4927
# Epoch [   11/   18] | d_loss: 0.0413 | g_loss: 2.8628
# Epoch [   11/   18] | d_loss: 0.0649 | g_loss: 3.6366
# Epoch [   11/   18] | d_loss: 0.0493 | g_loss: 4.5679
# Epoch [   11/   18] | d_loss: 0.1182 | g_loss: 2.8497
# Epoch [   12/   18] | d_loss: 0.0839 | g_loss: 2.6613
# Epoch [   12/   18] | d_loss: 0.0196 | g_loss: 2.5902
# Epoch [   12/   18] | d_loss: 0.2094 | g_loss: 2.3950
# Epoch [   12/   18] | d_loss: 0.0983 | g_loss: 4.1289
# Epoch [   12/   18] | d_loss: 0.1126 | g_loss: 4.3126
# Epoch [   12/   18] | d_loss: 0.1501 | g_loss: 2.9483
# Epoch [   12/   18] | d_loss: 0.1029 | g_loss: 2.5186
# Epoch [   12/   18] | d_loss: 0.7410 | g_loss: 3.0092
# Epoch [   12/   18] | d_loss: 0.0831 | g_loss: 5.5985
# Epoch [   12/   18] | d_loss: 0.1331 | g_loss: 3.8549
# Epoch [   12/   18] | d_loss: 0.2541 | g_loss: 3.7767
# Epoch [   12/   18] | d_loss: 0.0487 | g_loss: 5.4499
# Epoch [   12/   18] | d_loss: 0.1067 | g_loss: 3.0167
# Epoch [   12/   18] | d_loss: 0.0886 | g_loss: 3.6142
# Epoch [   12/   18] | d_loss: 0.0118 | g_loss: 3.2179
# Epoch [   13/   18] | d_loss: 0.1329 | g_loss: 2.4348
# Epoch [   13/   18] | d_loss: 0.1237 | g_loss: 3.9079
# Epoch [   13/   18] | d_loss: 0.0740 | g_loss: 3.7100
# Epoch [   13/   18] | d_loss: 0.4807 | g_loss: 2.9585
# Epoch [   13/   18] | d_loss: 0.1096 | g_loss: 2.1710
# Epoch [   13/   18] | d_loss: 0.1400 | g_loss: 3.3189
# Epoch [   13/   18] | d_loss: 0.1602 | g_loss: 2.7556
# Epoch [   13/   18] | d_loss: 0.0398 | g_loss: 4.6362
# Epoch [   13/   18] | d_loss: 0.0645 | g_loss: 3.6101
# Epoch [   13/   18] | d_loss: 0.2782 | g_loss: 3.1727
# Epoch [   13/   18] | d_loss: 0.3485 | g_loss: 3.1488
# Epoch [   13/   18] | d_loss: 0.3804 | g_loss: 2.7575
# Epoch [   13/   18] | d_loss: 0.0559 | g_loss: 2.7975
# Epoch [   13/   18] | d_loss: 0.2275 | g_loss: 2.5431
# Epoch [   13/   18] | d_loss: 0.0413 | g_loss: 3.7998
# Epoch [   14/   18] | d_loss: 0.0075 | g_loss: 4.6109
# Epoch [   14/   18] | d_loss: 0.0681 | g_loss: 4.2912
# Epoch [   14/   18] | d_loss: 0.0751 | g_loss: 4.3136
# Epoch [   14/   18] | d_loss: 0.0794 | g_loss: 3.2862
# Epoch [   14/   18] | d_loss: 0.1742 | g_loss: 3.1717
# Epoch [   14/   18] | d_loss: 0.1272 | g_loss: 3.0776
# Epoch [   14/   18] | d_loss: 0.1038 | g_loss: 2.3345
# Epoch [   14/   18] | d_loss: 0.0477 | g_loss: 2.7445
# Epoch [   14/   18] | d_loss: 0.1293 | g_loss: 2.4036
# Epoch [   14/   18] | d_loss: 0.1594 | g_loss: 5.4985
# Epoch [   14/   18] | d_loss: 0.0500 | g_loss: 3.5372
# Epoch [   14/   18] | d_loss: 0.0441 | g_loss: 2.9967
# Epoch [   14/   18] | d_loss: 0.1240 | g_loss: 3.7259
# Epoch [   14/   18] | d_loss: 0.0922 | g_loss: 3.6016
# Epoch [   14/   18] | d_loss: 0.0209 | g_loss: 4.0125
# Epoch [   15/   18] | d_loss: 0.0906 | g_loss: 3.0479
# Epoch [   15/   18] | d_loss: 0.0941 | g_loss: 3.4934
# Epoch [   15/   18] | d_loss: 0.0512 | g_loss: 2.1431
# Epoch [   15/   18] | d_loss: 0.0982 | g_loss: 2.0599
# Epoch [   15/   18] | d_loss: 0.0480 | g_loss: 3.2485
# Epoch [   15/   18] | d_loss: 0.0504 | g_loss: 2.5136
# Epoch [   15/   18] | d_loss: 0.1316 | g_loss: 2.3907
# Epoch [   15/   18] | d_loss: 0.0842 | g_loss: 3.4937
# Epoch [   15/   18] | d_loss: 0.0843 | g_loss: 2.4332
# Epoch [   15/   18] | d_loss: 0.0571 | g_loss: 3.4796
# Epoch [   15/   18] | d_loss: 0.1234 | g_loss: 4.0562
# Epoch [   15/   18] | d_loss: 0.1070 | g_loss: 2.7597
# Epoch [   15/   18] | d_loss: 0.4968 | g_loss: 4.3553
# Epoch [   15/   18] | d_loss: 0.0633 | g_loss: 4.3564
# Epoch [   15/   18] | d_loss: 0.0447 | g_loss: 5.5819
# Epoch [   16/   18] | d_loss: 0.0746 | g_loss: 3.6544
# Epoch [   16/   18] | d_loss: 0.0229 | g_loss: 3.6271
# Epoch [   16/   18] | d_loss: 0.0920 | g_loss: 4.0651
# Epoch [   16/   18] | d_loss: 0.0757 | g_loss: 4.2200
# Epoch [   16/   18] | d_loss: 0.1180 | g_loss: 2.7756
# Epoch [   16/   18] | d_loss: 0.0738 | g_loss: 4.9747
# Epoch [   16/   18] | d_loss: 0.1434 | g_loss: 2.2824
# Epoch [   16/   18] | d_loss: 0.5203 | g_loss: 2.2558
# Epoch [   16/   18] | d_loss: 0.0823 | g_loss: 3.3386
# Epoch [   16/   18] | d_loss: 0.0643 | g_loss: 3.6764
# Epoch [   16/   18] | d_loss: 0.0760 | g_loss: 2.7425
# Epoch [   16/   18] | d_loss: 0.0663 | g_loss: 3.5492
# Epoch [   16/   18] | d_loss: 0.0788 | g_loss: 3.0002
# Epoch [   16/   18] | d_loss: 0.1176 | g_loss: 3.5852
# Epoch [   16/   18] | d_loss: 0.0414 | g_loss: 3.6425
# Epoch [   17/   18] | d_loss: 0.0524 | g_loss: 2.7548
# Epoch [   17/   18] | d_loss: 0.1074 | g_loss: 4.4227
# Epoch [   17/   18] | d_loss: 0.1548 | g_loss: 2.9142
# Epoch [   17/   18] | d_loss: 0.0521 | g_loss: 5.4065
# Epoch [   17/   18] | d_loss: 0.1179 | g_loss: 2.2169
# Epoch [   17/   18] | d_loss: 0.0172 | g_loss: 3.2034
# Epoch [   17/   18] | d_loss: 0.0685 | g_loss: 3.8679
# Epoch [   17/   18] | d_loss: 0.2225 | g_loss: 3.9176
# Epoch [   17/   18] | d_loss: 0.0321 | g_loss: 4.2032
# Epoch [   17/   18] | d_loss: 0.0283 | g_loss: 4.1221
# Epoch [   17/   18] | d_loss: 0.0255 | g_loss: 2.6513
# Epoch [   17/   18] | d_loss: 0.2973 | g_loss: 3.0917
# Epoch [   17/   18] | d_loss: 0.0952 | g_loss: 3.1541
# Epoch [   17/   18] | d_loss: 0.0701 | g_loss: 3.3659
# Epoch [   17/   18] | d_loss: 0.0407 | g_loss: 3.3836
# Epoch [   18/   18] | d_loss: 0.3048 | g_loss: 3.3566
# Epoch [   18/   18] | d_loss: 0.0624 | g_loss: 2.8400
# Epoch [   18/   18] | d_loss: 0.1560 | g_loss: 2.2971
# Epoch [   18/   18] | d_loss: 0.0538 | g_loss: 3.8148
# Epoch [   18/   18] | d_loss: 0.0560 | g_loss: 3.6368
# Epoch [   18/   18] | d_loss: 0.1439 | g_loss: 4.1295
# Epoch [   18/   18] | d_loss: 0.0323 | g_loss: 3.3561
# Epoch [   18/   18] | d_loss: 0.0950 | g_loss: 3.5158
# Epoch [   18/   18] | d_loss: 0.0100 | g_loss: 5.5782
# Epoch [   18/   18] | d_loss: 0.1651 | g_loss: 3.2799
# Epoch [   18/   18] | d_loss: 0.0271 | g_loss: 3.5775
# Epoch [   18/   18] | d_loss: 0.3756 | g_loss: 2.5344
# Epoch [   18/   18] | d_loss: 0.1066 | g_loss: 4.0621
# Epoch [   18/   18] | d_loss: 0.0625 | g_loss: 3.9429
# Epoch [   18/   18] | d_loss: 0.3009 | g_loss: 4.0694

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples4.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** Training for a larger number of epochs would result in a better image.I have already used a larger Generator compared to the discriminator. The layer of generator had a maximum size of 256 while discriminator had a size of 64. I had used a Binary Cross entropy with logit loss for the optimizer. The optimizer used was Adams and i had Beta1 =0.5 and Beta2 =0.999(taken from the DCGAN paper).

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
